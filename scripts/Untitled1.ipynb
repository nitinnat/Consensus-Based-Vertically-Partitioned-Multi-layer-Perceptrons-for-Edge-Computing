# %%
import pandas as pd
import matplotlib.pyplot as plt
base_dir = "C:\\Users\\nitin\\eclipse-workspace\\consensus-deep-learning-version-2.0\\data\\arcene\\feature_split_1\\distributed_TrainLosses.csv"
df = pd.read_csv(base_dir, header=0)

# %%
fig, ax = plt.subplots()
# df = df[df["Iter"]%20==0]
df.groupby(["Iter", "Node"]).mean()["TrainLoss"].unstack().plot(ax=ax, legend=False)
